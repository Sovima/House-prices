# %% [markdown]
# # House Prices - v1

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier

'''

Change the long replace functions with Label Encoding!!!!

'''
house_data = pd.read_csv("/Users/sofyamalashchenko/Documents/Sofya/data s. corona/house-prices-advanced-regression-techniques/train.csv")
test_data = pd.read_csv("/Users/sofyamalashchenko/Documents/Sofya/data s. corona/house-prices-advanced-regression-techniques/test.csv")
def forest_model(house_dummies, test_dummies):
    X_train = house_dummies.drop("SalePrice", axis=1)
    X_val = test_dummies
    Y_train =  house_dummies["SalePrice"].copy()

    random_forest = RandomForestClassifier(n_estimators=100)
    random_forest.fit(X_train, Y_train)
    Y_prediction = pd.DataFrame(random_forest.predict(X_val))
    return Y_prediction
def forest_model2(house_dummies, SalePrice, test_dummies):
    X_train = house_dummies
    X_val = test_dummies
    Y_train =  SalePrice

    random_forest = RandomForestClassifier(n_estimators=100)
    random_forest.fit(X_train, Y_train)
    Y_prediction = pd.DataFrame(random_forest.predict(X_val))
    return Y_prediction

def models(house_dummies):
    sales = house_dummies["SalePrice"].copy()
    rest_data = house_dummies.drop("SalePrice", axis=1)
    X_train, X_val, Y_train, Y_val = train_test_split(rest_data, 
                                                      sales, 
                                                      random_state = 0)

    #SGD Classifier
    sgd = linear_model.SGDClassifier(max_iter=5, tol=None)
    sgd.fit(X_train, Y_train)
    Y_pred = sgd.predict(X_val)
    acc_sgd = mean_absolute_error(Y_val, Y_pred)
    #Random Forest
    random_forest = RandomForestClassifier(n_estimators=100)
    random_forest.fit(X_train, Y_train)
    Y_prediction = random_forest.predict(X_val)
    acc_random_forest = mean_absolute_error(Y_val, Y_prediction)
    #
    return acc_sgd, acc_random_forest


def missing_values(house_data):
    total = house_data.isnull().sum().sort_values(ascending=False)
    percent_1 = house_data.isnull().sum()/house_data.isnull().count()*100
    percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
    missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
    return missing_data.head(10)

label_encoder_cols = ["PoolQC", "FireplaceQu", "GarageFinish", 
                      "GarageYrBlt", "GarageCond", 'GarageQual', 
                      'BsmtExposure', 'BsmtFinType2', "BsmtQual", "BsmtCond", "BsmtFinType1"]




def poolQC_replace(house_data):
    house_data["PoolQC"] = house_data["PoolQC"].replace("Ex", 4)
    house_data["PoolQC"] = house_data["PoolQC"].replace("Gd", 3)
    house_data["PoolQC"] = house_data["PoolQC"].replace("TA", 2)
    house_data["PoolQC"] = house_data["PoolQC"].replace("Fa", 1)
    house_data["PoolQC"] = house_data["PoolQC"].fillna(0)

def FireplaceQu_replace(house_data):
    house_data["FireplaceQu"] = house_data["FireplaceQu"].replace("Ex", 5)
    house_data["FireplaceQu"] = house_data["FireplaceQu"].replace("Gd", 4)
    house_data["FireplaceQu"] = house_data["FireplaceQu"].replace("TA", 3)
    house_data["FireplaceQu"] = house_data["FireplaceQu"].replace("Fa", 2)
    house_data["FireplaceQu"] = house_data["FireplaceQu"].replace("Po", 1)
    house_data["FireplaceQu"] = house_data["FireplaceQu"].fillna(0)

def missing_mean(missing_mean_values, columns):
    mean = missing_mean_values[columns].mean()
    std = missing_mean_values[columns].std()
    is_null = missing_mean_values[columns].isnull().sum()
    rand_mean = np.random.randint(mean-std, mean+std, size = is_null)
    house_dummies_slice = missing_mean_values[columns].copy()
    house_dummies_slice[np.isnan(house_dummies_slice)] = rand_mean
    missing_mean_values[columns] = house_dummies_slice
    missing_mean_values[columns] = missing_mean_values[columns].astype(float)
    
def Garage_replace(house_data):
    house_data["GarageFinish"] = house_data["GarageFinish"].replace("Fin", 3)
    house_data["GarageFinish"] = house_data["GarageFinish"].replace("RFn", 2) 
    house_data["GarageFinish"] = house_data["GarageFinish"].replace("Unf", 1)
    house_data["GarageFinish"] = house_data["GarageFinish"].fillna(0)
    house_data["GarageYrBlt"] = house_data["GarageYrBlt"].replace("Fin", 3)
    house_data["GarageYrBlt"] = house_data["GarageYrBlt"].replace("RFn", 2) 
    house_data["GarageYrBlt"] = house_data["GarageYrBlt"].replace("Unf", 1)
    house_data["GarageYrBlt"] = house_data["GarageYrBlt"].fillna(0)
    house_data["GarageCond"] = house_data["GarageCond"].replace("Ex", 5)
    house_data["GarageCond"] = house_data["GarageCond"].replace("Gd", 4)
    house_data["GarageCond"] = house_data["GarageCond"].replace("TA", 3)
    house_data["GarageCond"] = house_data["GarageCond"].replace("Fa", 2) 
    house_data["GarageCond"] = house_data["GarageCond"].replace("Po", 1)
    house_data["GarageCond"] = house_data["GarageCond"].fillna(0)
    house_data["GarageQual"] = house_data["GarageQual"].replace("Ex", 5)
    house_data["GarageQual"] = house_data["GarageQual"].replace("Gd", 4)
    house_data["GarageQual"] = house_data["GarageQual"].replace("TA", 3)
    house_data["GarageQual"] = house_data["GarageQual"].replace("Fa", 2) 
    house_data["GarageQual"] = house_data["GarageQual"].replace("Po", 1)
    house_data["GarageQual"] = house_data["GarageQual"].fillna(0)


def Bsmt_replace(house_data):
    house_data["BsmtExposure"] = house_data["BsmtExposure"].replace("Gd", 4)
    house_data["BsmtExposure"] = house_data["BsmtExposure"].replace("Av", 3) 
    house_data["BsmtExposure"] = house_data["BsmtExposure"].replace("Mn", 2)
    house_data["BsmtExposure"] = house_data["BsmtExposure"].replace("No", 1)
    house_data["BsmtExposure"] = house_data["BsmtExposure"].fillna(0)
    house_data["BsmtFinType2"] = house_data["BsmtFinType2"].replace("GLQ", 6)
    house_data["BsmtFinType2"] = house_data["BsmtFinType2"].replace("ALQ", 5) 
    house_data["BsmtFinType2"] = house_data["BsmtFinType2"].replace("BLQ", 4)
    house_data["BsmtFinType2"] = house_data["BsmtFinType2"].replace("Rec", 3)
    house_data["BsmtFinType2"] = house_data["BsmtFinType2"].replace("LwQ", 2) 
    house_data["BsmtFinType2"] = house_data["BsmtFinType2"].replace("Unf", 1)
    house_data["BsmtFinType2"] = house_data["BsmtFinType2"].fillna(0)
    house_data["BsmtQual"] = house_data["BsmtQual"].replace("Ex", 5)
    house_data["BsmtQual"] = house_data["BsmtQual"].replace("Gd", 4)
    house_data["BsmtQual"] = house_data["BsmtQual"].replace("TA", 3)
    house_data["BsmtQual"] = house_data["BsmtQual"].replace("Fa", 2) 
    house_data["BsmtQual"] = house_data["BsmtQual"].replace("Po", 1)
    house_data["BsmtQual"] = house_data["BsmtQual"].fillna(0)
    house_data["BsmtCond"] = house_data["BsmtCond"].replace("Ex", 5)
    house_data["BsmtCond"] = house_data["BsmtCond"].replace("Gd", 4)
    house_data["BsmtCond"] = house_data["BsmtCond"].replace("TA", 3)
    house_data["BsmtCond"] = house_data["BsmtCond"].replace("Fa", 2) 
    house_data["BsmtCond"] = house_data["BsmtCond"].replace("Po", 1)
    house_data["BsmtCond"] = house_data["BsmtCond"].fillna(0)
    house_data["GarageQual"] = house_data["GarageQual"].replace("Ex", 5)
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("GLQ", 6)
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("ALQ", 5) 
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("BLQ", 4)
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("Rec", 3)
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("LwQ", 2) 
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("Unf", 1)
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].fillna(0)

def Bsmt_replace_test(house_data):
    house_data["BsmtExposure"] = house_data["BsmtExposure"].replace("Gd", 4)
    house_data["BsmtExposure"] = house_data["BsmtExposure"].replace("Av", 3) 
    house_data["BsmtExposure"] = house_data["BsmtExposure"].replace("Mn", 2)
    house_data["BsmtExposure"] = house_data["BsmtExposure"].replace("No", 1)
    house_data["BsmtExposure"] = house_data["BsmtExposure"].fillna(0)
    house_data["BsmtQual"] = house_data["BsmtQual"].replace("Ex", 5)
    house_data["BsmtQual"] = house_data["BsmtQual"].replace("Gd", 4)
    house_data["BsmtQual"] = house_data["BsmtQual"].replace("TA", 3)
    house_data["BsmtQual"] = house_data["BsmtQual"].replace("Fa", 2) 
    house_data["BsmtQual"] = house_data["BsmtQual"].replace("Po", 1)
    house_data["BsmtQual"] = house_data["BsmtQual"].fillna(0)
    house_data["BsmtCond"] = house_data["BsmtCond"].replace("Ex", 5)
    house_data["BsmtCond"] = house_data["BsmtCond"].replace("Gd", 4)
    house_data["BsmtCond"] = house_data["BsmtCond"].replace("TA", 3)
    house_data["BsmtCond"] = house_data["BsmtCond"].replace("Fa", 2) 
    house_data["BsmtCond"] = house_data["BsmtCond"].replace("Po", 1)
    house_data["BsmtCond"] = house_data["BsmtCond"].fillna(0)
    house_data["GarageQual"] = house_data["GarageQual"].replace("Ex", 5)
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("GLQ", 6)
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("ALQ", 5) 
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("BLQ", 4)
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("Rec", 3)
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("LwQ", 2) 
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].replace("Unf", 1)
    house_data["BsmtFinType1"] = house_data["BsmtFinType1"].fillna(0)
what_to_do = {
"MiscFeature": "get_dummies",
"Alley": "get_dummies",
"Fence": "get_dummies",
"FireplaceQu": "ordered",
"LotFrontage": "replace missing with something",
"GarageType": "get_dummies",
"GarageQual": "ordered",
"GarageCond": "ordered",
"GarageFinish": "ordered",
"GarageYrBlt": "replace missing with something or check if there is a garage at all",
"BsmtExposure": "figure out no exposure vs no basement",
"BsmtFinType2": "figure out unfinished vs no basement",
"BsmtQual": "poor vs no basement",
"BsmtCond": "poor vs no basement",
"BsmtFinType1": "unfinished vs no basement",
"MasVnrArea": "replace missing with something",
"MasVnrType": "get_dummies",
"Electrical": "ordered"
}


house_data['Electrical'] = house_data['Electrical'].fillna("SBrkr")

Get_dummies = ["MiscFeature","Alley","Fence","GarageType","MasVnrType","MSZoning", "Street"
               , "LotConfig", "Neighborhood", "Condition1", "Condition2", "RoofStyle", "RoofMatl",
               "Exterior1st", "Exterior2nd", "Foundation", "Electrical", "SaleType"]
house_dummies =pd.get_dummies(data=house_data, columns = Get_dummies)

poolQC_replace(house_dummies)
FireplaceQu_replace(house_dummies)
missing_mean(house_dummies, "LotFrontage")
Garage_replace(house_data = house_dummies)
Bsmt_replace(house_dummies)


house_dummies["MasVnrArea"] = house_dummies["MasVnrArea"].fillna(0)





for i in house_dummies:
    try:
        house_dummies[i] = house_dummies[i].astype("float")        
    except:
        house_dummies[i] = house_dummies[i].astype("object")


object_columns = (house_dummies[(house_dummies.dtypes == object).index[house_dummies.dtypes == object]]).columns

for i in object_columns:
    n = 0
    for l in house_dummies[i].unique():
        house_dummies[i] = house_dummies[i].replace(l, float(n))
        n = n+1

house_dummies["Deck"] = house_dummies["WoodDeckSF"] + house_dummies["OpenPorchSF"] + house_dummies["EnclosedPorch"] + house_dummies["3SsnPorch"] + house_dummies["ScreenPorch"]
house_dummies["FullBathF"] = house_dummies["BsmtFullBath"] + house_dummies["FullBath"]


unnes_columns = ["Id","WoodDeckSF", "OpenPorchSF", "EnclosedPorch", 
                 "3SsnPorch", "ScreenPorch", "BsmtFullBath", 
                 "BsmtHalfBath", "FullBath"]

house_dummies = house_dummies.drop(columns = unnes_columns)
house_float = house_dummies[(house_dummies.dtypes == float).index[house_dummies.dtypes == float]]

house_float_corr = house_float.corr()
sales = house_float_corr['SalePrice']


small_corr = (house_float_corr["SalePrice"] > 0.20) | (house_float_corr["SalePrice"] < -0.20)
house_dummies = house_dummies[small_corr.index[small_corr]]


house_float_corr = house_dummies.corr()
sales = house_float_corr['SalePrice']



#work with test_data before predicting
test_data["FullBathF"] = test_data["BsmtFullBath"] + test_data["FullBath"]

test_data["Deck"] = test_data["WoodDeckSF"] + test_data["OpenPorchSF"] + test_data["EnclosedPorch"] + test_data["3SsnPorch"] + test_data["ScreenPorch"]

test_dummies = pd.get_dummies(data=test_data, columns = Get_dummies)
test_dummies = test_dummies[house_dummies.columns.drop("SalePrice")]

object_columns_test = (test_dummies[(test_dummies.dtypes == object).index[test_dummies.dtypes == object]]).columns


for i in object_columns_test:
    n = 0
    for l in test_dummies[i].unique():
        test_dummies[i] = test_dummies[i].replace(l, float(n))
        n = n+1

missing_mean(test_dummies, "LotFrontage")
missing_mean(test_dummies, "FullBathF")
missing_mean(test_dummies, "BsmtFinSF1")
missing_mean(test_dummies, "GarageArea")
missing_mean(test_dummies, "TotalBsmtSF")
missing_mean(test_dummies, "GarageCars")
missing_mean(test_dummies, "BsmtUnfSF")

test_dummies['GarageMissing'] = test_dummies["GarageYrBlt"] > 0
test_dummies["GarageYrBlt"] = test_dummies["GarageYrBlt"].fillna(0)
test_dummies["MasVnrArea"] = test_dummies["MasVnrArea"].fillna(0)

house_dummies['GarageMissing'] = house_dummies["GarageYrBlt"] > 0

y_train = house_dummies["SalePrice"]
house_dummies = house_dummies.drop("SalePrice", axis = 1)
test_dummies = test_dummies[set(house_dummies.columns)]

predictions = pd.DataFrame(test_data["Id"]).copy()
predictions["SalePrice"] = pd.DataFrame(forest_model2(house_dummies, y_train, test_dummies))
